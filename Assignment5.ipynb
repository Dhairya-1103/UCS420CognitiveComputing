# %% [markdown]
# <a href="https://colab.research.google.com/github/Dhairya-1103/UCS420CognitiveComputing/blob/main/Assignment5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np

arr = np.array([10, 20, 30, 40, 50])

addition = arr + 2
print("After adding 2:", addition)

multiplication = arr * 3
print("After multiplying by 3:", multiplication)

division = arr / 2
print("After dividing by 2:", division)

# %%
import numpy as np

arr = np.array([1, 2, 3, 6, 4, 5])

reverse = arr[::-1]

print("Original array:", arr)
print("Reversed array:", reverse)

# %%
import numpy as np

x = np.array([1, 2, 3, 4, 5, 1, 2, 1, 1, 1])

values, counts = np.unique(x, return_counts=True)

most_frequent = values[np.argmax(counts)]
indices = np.where(x == most_frequent)[0]

print("Most frequent value:", most_frequent)
print("Frequency:", np.max(counts))
print("Indices:", indices)

# %%
import numpy as np

y = np.array([1, 1, 1, 2, 3, 4, 2, 4, 3, 3])

values, counts = np.unique(y, return_counts=True)

max_count = np.max(counts)
most_frequent = values[counts == max_count]

print("Most frequent values:", most_frequent)

for value in most_frequent:
    print("Value:", value)
    print("Indices:", np.where(y == value)[0])

# %%
import numpy as np

arr = np.array([
    [10, 20, 30],
    [40, 50, 60],
    [70, 80, 90]
])

print("1st row, 2nd column:", arr[0, 1])
print("3rd row, 1st column:", arr[2, 0])

# %%
import numpy as np

Dhairya = np.linspace(10, 100, 25)

print("Array:", Dhairya)
print("Dimensions:", Dhairya.ndim)
print("Shape:", Dhairya.shape)
print("Total elements:", Dhairya.size)
print("Data type:", Dhairya.dtype)
print("Total bytes:", Dhairya.nbytes)

transpose = Dhairya.reshape(1, 25)

print("Reshaped array:")
print(transpose)

transpose = Dhairya.reshape(1, 25).T

print("Transpose using T:")
print(transpose)

# %%
import numpy as np

ucs420_Dhairya = np.array([
    [10, 20, 30, 40],
    [50, 60, 70, 80],
    [90, 15, 20, 35]
])

print("Original Array:")
print(ucs420_Dhairya)

print("Mean:", np.mean(ucs420_Dhairya))
print("Median:", np.median(ucs420_Dhairya))
print("Maximum:", np.max(ucs420_Dhairya))
print("Minimum:", np.min(ucs420_Dhairya))
print("Unique Elements:", np.unique(ucs420_Dhairya))

reshaped_ucs420_Dhairya = ucs420_Dhairya.reshape(4, 3)

print("Reshaped Array:")
print(reshaped_ucs420_Dhairya)

resized_ucs420_Dhairya = np.resize(ucs420_Dhairya, (2, 3))

print("Resized Array:")
print(resized_ucs420_Dhairya)
